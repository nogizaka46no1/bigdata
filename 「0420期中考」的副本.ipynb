# %% [markdown]
# <a href="https://colab.research.google.com/github/nogizaka46no1/bigdata/blob/main/%E3%80%8C0420%E6%9C%9F%E4%B8%AD%E8%80%83%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(SportsAnalytics)

# %%
library(ggplot2)

# %%
NBA1516<-fetch_NBAPlayerStatistics("15-16")

# %%
NBA1516OrederM<-NBA1516[order(NBA1516$TotalPoints,decreasing=T),]
NBA1516OrederM[1:20,"Name"]
# Out:
#  [1] "James Harden"     "Stephen Curry"    "Kevin Durant"     "Lebron James"
#  [5] "Damian Lillard"   "Russel Westbrook" "Paul George"      "Demar Derozan"
#  [9] "Isaiah Thomas"    "Klay Thompson"    "Demarcus Cousins" "Kemba Walker"
# [13] "Andrew Wiggins"   "C.j. Mccollum"    "Kyle Lowry"       "Gordon Hayward"
# [17] "Carmelo Anthony"  "John Wall"        "Kawhi Leonard"    "Karl-antho Towns"

# %%
install.packages("data.table")
library(data.table)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
subset(NBA1516,Team=="CLE")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 114 NBA    Matt Dellavedova CLE  PG       76          1869
# 146 NBA    Channing Frye    CLE  PF       70          1196
# 184 NBA    Joe Harris       CLE  SG        5            15
# 219 NBA    Kyrie Irving     CLE  PG       53          1665
# 222 NBA    Lebron James     CLE  SF       76          2710
# 225 NBA    Richar Jefferson CLE  SF       74          1326
# 238 NBA    Dahntay Jones    CLE  SG        1            42
# 239 NBA    James Jones      CLE  SG       48           466
# 248 NBA    Sasha Kaun       CLE  C        24            96
# 273 NBA    Kevin Love       CLE  PF       77          2424
# 296 NBA    Jordan Mcrae     CLE  SG       22           197
# 318 NBA    Timofey Mozgov   CLE  C        76          1329
# 395 NBA    Iman Shumpert    CLE  SG       54          1319
# 403 NBA    J.r. Smith       CLE  SG       77          2367
# 427 NBA    Tristan Thompson CLE  C        82          2269
# ...

# %%
NBA1516[grepl("Lebron",NBA1516$Name),]
# Out:
#     League Name         Team Position GamesPlayed TotalMinutesPlayed
# 222 NBA    Lebron James CLE  SF       76          2710
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 222 737            1416                87         282             ⋯ 104
#     Turnovers Blocks PersonalFouls Disqualifications TotalPoints Technicals
# 222 249       49     143           0                 1920        3
#     Ejections FlagrantFouls GamesStarted
# 222 0         0             76

# %%
qplot(FieldGoalsAttempted, TotalPoints, data=NBA1516, color=Position ,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(FieldGoalsAttempted, data=NBA1516 ,geom="bar",weight=TotalPoints)
# Out:
# plot without title

# %%
qplot(mpg, data = mtcars, geom = "density",
  fill = gear, alpha = I(.5),
  main="NBA1516",
  xlab="FieldGoalsAttempted",
  ylab="TotalPoints")
# Out:
# plot without title

# %%
qplot(gear, mpg, data = mtcars, geom = c("boxplot", "jitter"),
   fill = gear, main = "NBA1516",
   xlab = "FieldGoalsAttempted", ylab = "TotalPoints")
# Out:
# Warning message:
# “Continuous x aesthetic -- did you forget aes(group=...)?”
# plot without title
