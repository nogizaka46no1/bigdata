# %% [markdown]
# <a href="https://colab.research.google.com/github/nogizaka46no1/bigdata/blob/main/%E3%80%8C0323_2%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message in install.packages("ggplot2"):
# “installation of package ‘ggplot2’ had non-zero exit status”

# %%
library(SportsAnalytics)

# %%
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
NBA1920<-fetch_NBAPlayerStatistics("19-20")

# %%
qplot(FieldGoalsAttempted, TotalPoints, data=NBA1920, color=Position ,geom=c("point","smooth"))
# Out:
# Error in qplot(FieldGoalsAttempted, TotalPoints, data = NBA1920, color = Position, : could not find function "qplot"
# Traceback:

# %%
qplot( TotalPoints, data=NBA1920, fill=Position )
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(ThreesAttempted, TotalPoints, data=NBA1920, color=Position,
geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(ThreesAttempted, data=NBA1920,fill=Team)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data=NBA1920,facets=.~Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,TotalPoints,data = NBA1920,facets=  Position~.)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,ThreesAttempted,data=NBA1920,facets=.~Position)
# Out:
# plot without title

# %%
qplot(FieldGoalsAttempted,ThreesAttempted,data = NBA1920,facets=  Position~.)
# Out:
# plot without title
